# %% [markdown]
# # Data Visualisation
#
# - Hypothesis: habitat destruction & climate change are having an impact on shark's and may help better explain why
#   attacks are increasing
# - SubHypothesis: Technological developments are allowing humans to better record and deter shark attacks.

# %% [markdown]
# ![Screenshot%202022-10-15%20at%2016.42.45.png](attachment:Screenshot%202022-10-15%20at%2016.42.45.png)

# %% [markdown]
# - https://www.theguardian.com/environment/2021/feb/09/climate-crisis-pushing-great-white-sharks-into-new-waters

# %%
#Tools Import

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams
import re
pd.options.mode.chained_assignment = None

# %%
new_df = pd.read_csv("./data/new_df.csv")

# %%
new_df
# Out:
#      Date  Year       Country  \
# 0     jun  2018           USA
# 1     jun  2018        MEXICO
# 2     jun  2018        BRAZIL
# 3     may  2018           USA
# 4     may  2018           USA
# ...   ...   ...           ...
# 1705  dec  1907     AUSTRALIA
# 1706  mar  1907         MALTA
# 1707  aug  1905         EGYPT
# 1708  jan  1903     AUSTRALIA
# 1709  jul  1901  SOUTH AFRICA
#
#                                                Activity Sex   Age Fatal (Y/N)  \
# 0                                              Paddling   F  57.0           N
# 1                                           Free diving   M   NaN           N
# 2                                              Swimming   M  18.0           Y
# 3                                               Fishing   M  52.0           N
# 4                                               Walking   M  15.0           N
# ...                                                 ...  ..   ...         ...
# 1705                                            Bathing   M   NaN           Y
# 1706                                            Fishing   M   NaN           Y
# 1707  Human head found in shark caught by British st...   M   NaN         NaN
# 1708                                                NaN   M   NaN           Y
# 1709                                           Swimming   M  29.0           Y
#
#           Species
# 0     White shark
# 1     Tiger shark
# 2     Tiger shark
# 3     Lemon shark
# 4      Bull shark
# ...           ...
# 1705   Bull shark
# 1706  White shark
# 1707  Tiger shark
# 1708   Bull shark
# 1709  White shark
#
# [1710 rows x 8 columns]

# %%
sns.scatterplot(x="Species", y= "Year" , hue="Fatal (Y/N)", data=new_df, palette="pastel");

# %% [markdown]
# - histplot
# - lineplot
# - barchart

# %%
sns.histplot(x="Year", y= "Species" , hue="Fatal (Y/N)", data=new_df, palette="pastel");

# %%
sns.histplot(data=clean_data_set, x="Year", hue="Fatal (Y/N)", multiple="dodge", bins=15)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Count'>

# %%
sns.histplot(data=clean_data_set, x="Age", hue="Fatal (Y/N)", bins=15)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=clean_data_set, x="Country".nlarge, hue="Fatal (Y/N)", bins=15)

# %%
sns.histplot(
    x='Year',
    y='Species',
    hue="Fatal (Y/N)",
    data= clean_data_set.sort_values('Species').head(10)
                                                )
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Species'>

# %%
#sns.histplot(x="Year", y= "Species" , hue="Fatal (Y/N)", data=clean_data_set.nlargest(10, "Species"));

# %%
list(clean_data_set["Species"])
# Out:
# ['White shark',
#  nan,
#  nan,
#  nan,
#  'Tiger shark',
#  nan,
#  'Tiger shark',
#  'Lemon shark',
#  'Bull shark',
#  nan,
#  'reef shark',
#  nan,
#  nan,
#  nan,
#  'nurse shark',
#  nan,
#  nan,
#  nan,
#  'Tiger shark',
#  nan,
#  nan,
#  nan,
#  'White shark',
#  'Tiger shark',
#  'White shark',
#  nan,
#  'bull shark',
#  nan,
#  nan,
#  nan,
#  'Tiger shark',
#  nan,
#  nan,
#  'Bull shark',
#  'White shark',
#  'Tiger shark',
#  'Wobbegong shark',
#  nan,
#  nan,
#  'Blacktip shark',
#  'white shark',
#  nan,
#  'Bull shark',
#  nan,
#  nan,
#  'Galapagos shark',
#  nan,
#  'Bull shark',
#  'Bull shark',
#  'reef shark',
#  'White shark',
#  'small shark',
#  'Wobbegong shark',
#  'Tiger shark',
#  nan,
#  'nurse shark',
#  'Nurse shark',
#  'Tiger shark',
#  'Tiger shark',
#  'blue shark',
#  'White shark',
#  nan,
#  nan,
#  nan,
#  'Tiger shark',
#  'Cookiecutter shark',
#  'Wobbegong shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  'Spinner shark',
#  'Tiger shark',
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  nan,
#  'White shark',
#  nan,
#  nan,
#  nan,
#  'Nurse shark',
#  nan,
#  nan,
#  'White shark',
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  'blacktip shark',
#  'whitetip shark',
#  nan,
#  'White shark',
#  nan,
#  'small shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Sandtiger shark',
#  'Blue shark',
#  'small shark',
#  nan,
#  'White shark',
#  'White shark',
#  'White shark',
#  nan,
#  'White shark',
#  'Bull shark',
#  'Tiger shark',
#  'White shark',
#  nan,
#  'No shark',
#  nan,
#  nan,
#  'Bull shark',
#  'Bull shark',
#  nan,
#  nan,
#  nan,
#  'White shark',
#  'gill shark',
#  nan,
#  nan,
#  nan,
#  'Tiger shark',
#  nan,
#  'Tiger shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'No shark',
#  nan,
#  nan,
#  nan,
#  'White shark',
#  'Tiger shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bull shark',
#  nan,
#  nan,
#  'White shark',
#  nan,
#  'Lemon shark',
#  'Bull shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Lemon shark',
#  'Tiger shark',
#  'White shark',
#  'reef shark',
#  nan,
#  nan,
#  'Bull shark',
#  nan,
#  nan,
#  'Bull shark',
#  nan,
#  nan,
#  nan,
#  'small shark',
#  'White shark',
#  nan,
#  nan,
#  nan,
#  'Wobbegong shark',
#  'White shark',
#  'sevengill shark',
#  'Tiger shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Tiger shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  'Bull shark',
#  nan,
#  'Bull shark',
#  nan,
#  nan,
#  'Tiger shark',
#  'Blacktip shark',
#  'Blue shark',
#  nan,
#  'White shark',
#  'Nurse shark',
#  nan,
#  nan,
#  nan,
#  'Bull shark',
#  'reef shark',
#  'Tiger shark',
#  nan,
#  nan,
#  'White shark',
#  nan,
#  'Lemon shark',
#  'Angel shark',
#  'White shark',
#  'dogfish shark',
#  'White shark',
#  nan,
#  'nurse shark',
#  nan,
#  nan,
#  'reef shark',
#  'White shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Mako shark',
#  'whaler shark',
#  nan,
#  'White shark',
#  nan,
#  nan,
#  nan,
#  'Bull shark',
#  nan,
#  'Blacktip shark',
#  'Nurse shark',
#  nan,
#  'Mako shark',
#  'Bull shark',
#  nan,
#  'White shark',
#  'Wobbegong shark',
#  'reef shark',
#  'reef shark',
#  'Bull shark',
#  'Tiger shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Nurse shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Sandtiger shark',
#  nan,
#  nan,
#  nan,
#  'No shark',
#  'No shark',
#  nan,
#  nan,
#  'Sandtiger shark',
#  nan,
#  'Reef shark',
#  nan,
#  'Bull shark',
#  'Mako shark',
#  'Tiger shark',
#  'Wobbegong shark',
#  'Blacktip shark',
#  nan,
#  'White shark',
#  'Silky shark',
#  nan,
#  'whaler shark',
#  'Tiger shark',
#  nan,
#  'White shark',
#  'Bull shark',
#  nan,
#  'Galapagos shark',
#  nan,
#  nan,
#  'Spinner shark',
#  'Bull shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  'Spinner shark',
#  nan,
#  'No shark',
#  'Tiger shark',
#  nan,
#  nan,
#  'Tiger shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Blacktip shark',
#  'Blacktip shark',
#  nan,
#  'White shark',
#  'juvenile shark',
#  'Tiger shark',
#  nan,
#  nan,
#  'Hammerhead shark',
#  nan,
#  nan,
#  nan,
#  'White shark',
#  'Hammerhead shark',
#  'White shark',
#  nan,
#  'small shark',
#  'Tiger shark',
#  'White shark',
#  'White shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  'Hammerhead shark',
#  'White shark',
#  nan,
#  nan,
#  'spinner shark',
#  'but shark',
#  'White shark',
#  'Mako shark',
#  'whaler shark',
#  'Bull shark',
#  'White shark',
#  'White shark',
#  nan,
#  'No shark',
#  nan,
#  nan,
#  'White shark',
#  'White shark',
#  nan,
#  nan,
#  nan,
#  'Bull shark',
#  'White shark',
#  nan,
#  'White shark',
#  nan,
#  'Wobbegong shark',
#  nan,
#  'Sandtiger shark',
#  'White shark',
#  'small shark',
#  nan,
#  nan,
#  'Bull shark',
#  'Bull shark',
#  'Mako shark',
#  nan,
#  'Bull shark',
#  'nurse shark',
#  'Bull shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bull shark',
#  nan,
#  'White shark',
#  'White shark',
#  nan,
#  'foot shark',
#  'White shark',
#  'White shark',
#  'Blue shark',
#  'Bull shark',
#  nan,
#  'Bull shark',
#  nan,
#  'No shark',
#  'White shark',
#  'Mako shark',
#  'Tiger shark',
#  'Blacktip shark',
#  nan,
#  nan,
#  'Reef shark',
#  'White shark',
#  'Tiger shark',
#  nan,
#  nan,
#  nan,
#  'Bull shark',
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  nan,
#  nan,
#  'No shark',
#  'White shark',
#  'Raggedtooth shark',
#  'small shark',
#  nan,
#  'White shark',
#  nan,
#  nan,
#  'White shark',
#  nan,
#  'Goblin shark',
#  'Tiger shark',
#  nan,
#  nan,
#  nan,
#  'White shark',
#  'White shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Tiger shark',
#  nan,
#  'Tiger shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bull shark',
#  nan,
#  nan,
#  'Blacktip shark',
#  nan,
#  'Blacktip shark',
#  'White shark',
#  'White shark',
#  nan,
#  'white shark',
#  nan,
#  'Blacktip shark',
#  'No shark',
#  nan,
#  'Bull shark',
#  'White shark',
#  nan,
#  nan,
#  'Spinner shark',
#  'Spinner shark',
#  nan,
#  nan,
#  'small shark',
#  nan,
#  nan,
#  'Bull shark',
#  nan,
#  'reef shark',
#  'Bull shark',
#  nan,
#  'Bull shark',
#  nan,
#  'Bull shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  'tiger shark',
#  'metre shark',
#  nan,
#  'Angel shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  nan,
#  'whitetip shark',
#  'reef shark',
#  nan,
#  nan,
#  'Lemon shark',
#  nan,
#  'Sandbar shark',
#  'whaler shark',
#  nan,
#  nan,
#  'Bull shark',
#  nan,
#  'Reef shark',
#  'Bull shark',
#  nan,
#  'nurse shark',
#  nan,
#  'white shark',
#  nan,
#  nan,
#  'No shark',
#  nan,
#  'Cow shark',
#  nan,
#  'reef shark',
#  nan,
#  nan,
#  'White shark',
#  'Raggedtooth shark',
#  nan,
#  nan,
#  'white shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'No shark',
#  'Wobbegong shark',
#  nan,
#  'spinner shark',
#  'reef shark',
#  nan,
#  nan,
#  nan,
#  'gill shark',
#  nan,
#  'gill shark',
#  nan,
#  'whitetip shark',
#  'White shark',
#  'bull shark',
#  'White shark',
#  nan,
#  'Tiger shark',
#  nan,
#  'Wobbegong shark',
#  nan,
#  'Tiger shark',
#  nan,
#  'white shark',
#  'White shark',
#  'white shark',
#  nan,
#  nan,
#  nan,
#  'Tiger shark',
#  'reef shark',
#  'bull shark',
#  'white shark',
#  'Wobbegong shark',
#  'reef shark',
#  'Tiger shark',
#  'Nurse shark',
#  'White shark',
#  'White shark',
#  'White shark',
#  'bull shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bull shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Nurse shark',
#  nan,
#  nan,
#  'Blacktip shark',
#  'Salmon shark',
#  'No shark',
#  'Mako shark',
#  nan,
#  nan,
#  nan,
#  'White shark',
#  'Tiger shark',
#  nan,
#  'Bull shark',
#  'Blacktip shark',
#  'Bull shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Tiger shark',
#  'Nurse shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  'Bull shark',
#  nan,
#  'Tiger shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Lemon shark',
#  nan,
#  'Galapagos shark',
#  nan,
#  nan,
#  nan,
#  'Galapagos shark',
#  nan,
#  'Bull shark',
#  'small shark',
#  nan,
#  'Tiger shark',
#  'nurse shark',
#  nan,
#  'Blue shark',
#  'Bull shark',
#  nan,
#  'reef shark',
#  nan,
#  nan,
#  nan,
#  'No shark',
#  nan,
#  'Nurse shark',
#  nan,
#  'Raggedtooth shark',
#  nan,
#  'Tiger shark',
#  'whaler shark',
#  'small shark',
#  nan,
#  'White shark',
#  'reef shark',
#  'reef shark',
#  'Blacktip shark',
#  'Lemon shark',
#  nan,
#  'White shark',
#  nan,
#  nan,
#  'Tiger shark',
#  'whaler shark',
#  nan,
#  nan,
#  nan,
#  'Bull shark',
#  'Tiger shark',
#  'Tiger shark',
#  nan,
#  'Sandtiger shark',
#  'gill shark',
#  'Tiger shark',
#  'No shark',
#  nan,
#  nan,
#  'Tiger shark',
#  'Tiger shark',
#  'White shark',
#  'Tiger shark',
#  'White shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'bull shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Tiger shark',
#  nan,
#  'Porbeagle shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Lemon shark',
#  'Bull shark',
#  'Lemon shark',
#  nan,
#  'White shark',
#  nan,
#  'white shark',
#  nan,
#  nan,
#  nan,
#  'Salmon shark',
#  'White shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'No shark',
#  'bull shark',
#  nan,
#  'reef shark',
#  nan,
#  nan,
#  nan,
#  'No shark',
#  nan,
#  'Nurse shark',
#  'blacktip shark',
#  nan,
#  'blacktip shark',
#  'Blacktip shark',
#  nan,
#  'Blue shark',
#  'White shark',
#  nan,
#  nan,
#  nan,
#  'Bull shark',
#  nan,
#  'Tiger shark',
#  nan,
#  'White shark',
#  nan,
#  'White shark',
#  nan,
#  'White shark',
#  'White shark',
#  'Tiger shark',
#  'small shark',
#  'White shark',
#  nan,
#  'White shark',
#  'bull shark',
#  'bull shark',
#  nan,
#  nan,
#  nan,
#  'nurse shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Spinner shark',
#  'nurse shark',
#  'White shark',
#  nan,
#  nan,
#  'Tiger shark',
#  'Tiger shark',
#  'Blue shark',
#  'White shark',
#  'bull shark',
#  'White shark',
#  nan,
#  'tiger shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  'Wobbegong shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Wobbegong shark',
#  'White shark',
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  'Raggedtooth shark',
#  'White shark',
#  'White shark',
#  'Jackson shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'No shark',
#  nan,
#  'White shark',
#  'Bull shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Tiger shark',
#  nan,
#  'White shark',
#  'spinner shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  'sandtiger shark',
#  nan,
#  nan,
#  'reef shark',
#  nan,
#  'Bull shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bull shark',
#  'Bull shark',
#  'White shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'whitetip shark',
#  'Blacktip shark',
#  nan,
#  'Sevengill shark',
#  nan,
#  'reef shark',
#  nan,
#  'White shark',
#  'Tiger shark',
#  'Tiger shark',
#  'Zambesi shark',
#  nan,
#  'Tiger shark',
#  nan,
#  'Sandbar shark',
#  nan,
#  nan,
#  'Bull shark',
#  'reef shark',
#  nan,
#  'whaler shark',
#  'Bull shark',
#  nan,
#  'Blacktip shark',
#  'Bull shark',
#  'Bull shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bull shark',
#  nan,
#  nan,
#  'White shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'reef shark',
#  nan,
#  nan,
#  nan,
#  'White shark',
#  nan,
#  nan,
#  nan,
#  'whitetip shark',
#  nan,
#  'Mako shark',
#  'Mako shark',
#  'whitetip shark',
#  'whitetip shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  'White shark',
#  nan,
#  nan,
#  nan,
#  'Porbeagle shark',
#  nan,
#  'White shark',
#  nan,
#  'Bull shark',
#  'Lemon shark',
#  'lemon shark',
#  nan,
#  'White shark',
#  nan,
#  'White shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  'White shark',
#  nan,
#  nan,
#  nan,
#  ...]
