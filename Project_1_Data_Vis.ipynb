# %% [markdown]
# # Data Visualisation
#
# - Hypothesis: habitat destruction & climate change are having an impact on shark's and may help better explain why
#   attacks are increasing
# - SubHypothesis: Technological developments are allowing humans to better record and deter shark attacks.

# %% [markdown]
# ![Screenshot%202022-10-15%20at%2016.42.45.png](attachment:Screenshot%202022-10-15%20at%2016.42.45.png)

# %% [markdown]
# - https://www.theguardian.com/environment/2021/feb/09/climate-crisis-pushing-great-white-sharks-into-new-waters

# %%
#Tools Import

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams
import re
pd.options.mode.chained_assignment = None

# %%
new_df = pd.read_csv("./data/new_df.csv")

# %%
new_df
# Out:
#      Date  Year       Country  \
# 0     jun  2018           USA
# 1     jun  2018        MEXICO
# 2     jun  2018        BRAZIL
# 3     may  2018           USA
# 4     may  2018           USA
# ...   ...   ...           ...
# 1705  dec  1907     AUSTRALIA
# 1706  mar  1907         MALTA
# 1707  aug  1905         EGYPT
# 1708  jan  1903     AUSTRALIA
# 1709  jul  1901  SOUTH AFRICA
#
#                                                Activity Sex   Age Fatal (Y/N)  \
# 0                                              Paddling   F  57.0           N
# 1                                           Free diving   M   NaN           N
# 2                                              Swimming   M  18.0           Y
# 3                                               Fishing   M  52.0           N
# 4                                               Walking   M  15.0           N
# ...                                                 ...  ..   ...         ...
# ...

# %%
sns.scatterplot(x="Species", y= "Year" , hue="Fatal (Y/N)", data=new_df, palette="pastel");

# %% [markdown]
# - histplot
# - lineplot
# - barchart

# %%
sns.histplot(x="Year", y= "Species" , hue="Fatal (Y/N)", data=new_df, palette="pastel");

# %% [markdown]
# ## Are shark attacks increasing?

# %%
sns.histplot(data=new_df, x="Year", hue="Fatal (Y/N)", multiple="dodge", bins=15)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Count'>

# %%
sns.histplot(data=new_df, x="Age", hue="Fatal (Y/N)", bins=15)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=new_df, x="Activity", hue="Fatal (Y/N)", bins=15)
# Out:
# <AxesSubplot:xlabel='Activity', ylabel='Count'>
# /Users/hugosaccount/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 150 (\x96) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hugosaccount/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hugosaccount/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 147 (\x93) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hugosaccount/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 148 (\x94) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.histplot(
    x='Year',
    y='Species',
    hue="Fatal (Y/N)",
    data= new_df.sort_values('Species').head(10)
                                                )
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Species'>

# %%
#sns.histplot(x="Year", y= "Species" , hue="Fatal (Y/N)", data=clean_data_set.nlargest(10, "Species"));

# %%
new_df["Country"].value_counts()[:15].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
new_df["Activity"].value_counts()[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>
